# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parent.parent))

# %%
import pandas as pd

# %%
from src.utils.visualization import Visualizer

# %%
df = pd.read_csv("../../data/raw/austo_automobile1.csv")

# %%
# Numerical variables
for col in ["Age", "Salary", "Partner_salary", "Total_salary", "Price", "No_of_Dependents"]:
    Visualizer.plot_histogram(df, col)
    Visualizer.plot_box(df, col)

# %%
# Categorical variables
for col in ["Gender", "Profession", "Marital_status", "Education", "Personal_loan", "House_loan", "Partner_working", "make"]:
    Visualizer.plot_count(df, col)
