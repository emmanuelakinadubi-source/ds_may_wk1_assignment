# %% [markdown]
# This project Showcase EDA - Exploratory Data Analysis on the Austo Business Data

# %% [markdown]
# Business Context

# %% [markdown]
# Austo aims to understand customer preferences and the factors influencing car purchases in the US market. In order to be familiar with the types of cars preferred by the customers and factors influencing the car purchase behavior in the US market, Austo has contracted a consulting firm. Based on various market surveys, the consulting firm has created a dataset of 3 major types of cars that are extensively used across the US market. They have collected various details of the car owners which can be analyzed to understand the automobile market of the US. Austo's management team wants to understand the demand of the buyers and trends in the US market. They want to build customer profiles based on the analysis to identify new purchase opportunities so that they can manipulate the business strategy and production to meet certain demand levels. Further, the analysis will be a good way for management to understand the dynamics of a new market. Your task as a data scientist is to explore the dataset, uncover patterns, identify key variables, and derive insights that can guide business decisions.

# %% [markdown]
# Data Dictionary
# * Age: Age of the customer
# * Gender: Gender of the customer
# * Profession: Indicates whether the customer is a salaried or business person
# * Marital_status: Marital status of the customer
# * Education: Refers to the highest level of education completed by the customer
# * No_of_dependents: Number of dependents(partner/children/spouse) of the customer
# * Personal_loan: Indicates whether the customer availed a personal loan or not
# * House_loan: Indicates whether the customer availed house loan or not
# * Partner_working: Indicates whether the customer's partner is working or not
# * Salary: Annual Salary of the customer
# * Partner_salary: Annual Salary of the customer's partner
# * Total_salary: Annual household income (Salary + Partner_salary) of the customer's family
# * Price: Price of the car
# * Make: Car type (Hatchback/Sedan/SUV)

# %% [markdown]
# Business Requirements
#
# 1. Data Understanding & Cleaning
#    - Inspect dataset shape, data types, and summary statistics
#    - Identify and handle missing values
#    - Detect and comment on outliers
#
# 2. Univariate Analysis
#    - Analyze key numerical and categorical variables
#    - Use appropriate visualizations (histograms, boxplots, count plots)
#
# 3. Bivariate Analysis
#    - Explore relationships between key variables
#    - Use scatter plots, bar plots, and correlation analysis
#
# 4. Insights & Interpretation
#    - Summarize insights from your analysis
#    - Clearly state business implications

# %% [markdown]
# GOAL -
# Deliverable
# - A clean, well-documented Jupyter Notebook
# - Clear visualizations with titles and interpretations

# %% [markdown]
# 1. IMPORTING MODULES

# %%
# <!-- IMPORTING MODULES  -->
from util.imports import * 

sns.set(style='whitegrid')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # <!-- IMPORTING MODULES  -->
# ----> 2 from util import *
#       4 sns.set(style='whitegrid')
#
# ModuleNotFoundError: No module named 'util'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# 2. LOADING DATASET: Austo automobile dataset

# %%
url = r'C:\Users\emman\Desktop\DATA_SCIENCE_ITC\MAY\DS_WK_1\DS_MAY_WK_1_ASSIGNMENT\data\austo_automobile 1.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    Age Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   24   Male   Salaried        Married  Post Graduate                 4
# 1   28   Male   Salaried        Married  Post Graduate                 3
# 2   23   Male   Salaried        Married       Graduate                 4
# 3   26   Male   Business        Married  Post Graduate                 4
# 4   28   Male   Business        Married  Post Graduate                 4
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No        Yes             Yes   52000           25000
# 1            No        Yes              No   68000               0
# 2           Yes        Yes              No   31000               0
# 3           Yes        Yes             Yes   66000           35000
# 4           Yes         No              No   64000               0
#
#    Total_salary  Price       Make
# 0         77000  18000  Hatchback
# 1         68000  18000  Hatchback
# ...

# %% [markdown]
#  3. Data Understanding & Cleaning

# %% [markdown]
# - Inspect dataset shape
# - data types
# - summary statistics

# %% [markdown]
# i. Inspect dataset shape

# %%
# Data Shape
df.shape
# Out:
# (1581, 14)

# %% [markdown]
# ii. data types

# %%
# Data types
df.dtypes
# Out:
# Age                  int64
# Gender              object
# Profession          object
# Marital_status      object
# Education           object
# No_of_Dependents     int64
# Personal_loan       object
# House_loan          object
# Partner_working     object
# Salary               int64
# Partner_salary       int64
# Total_salary         int64
# Price                int64
# Make                object
# dtype: object

# %% [markdown]
# iii. Summary statistics

# %%
# Data Summary statistics
df.describe
# Out:
# <bound method NDFrame.describe of       Age Gender Profession Marital_status      Education  No_of_Dependents  \
# 0      24   Male   Salaried        Married  Post Graduate                 4
# 1      28   Male   Salaried        Married  Post Graduate                 3
# 2      23   Male   Salaried        Married       Graduate                 4
# 3      26   Male   Business        Married  Post Graduate                 4
# 4      28   Male   Business        Married  Post Graduate                 4
# ...   ...    ...        ...            ...            ...               ...
# 1576   28   Male   Salaried        Married  Post Graduate                 2
# 1577   23   Male   Salaried         Single       Graduate                 2
# 1578   23   Male   Business        Married       Graduate                 4
# 1579   25   Male   Business        Married  Post Graduate                 3
# 1580   28   Male   Salaried        Married       Graduate                 4
#
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Profession', 'Marital_status', 'Education',
#        'No_of_Dependents', 'Personal_loan', 'House_loan', 'Partner_working',
#        'Salary', 'Partner_salary', 'Total_salary', 'Price', 'Make'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of       Age Gender Profession Marital_status      Education  No_of_Dependents  \
# 0      24   Male   Salaried        Married  Post Graduate                 4
# 1      28   Male   Salaried        Married  Post Graduate                 3
# 2      23   Male   Salaried        Married       Graduate                 4
# 3      26   Male   Business        Married  Post Graduate                 4
# 4      28   Male   Business        Married  Post Graduate                 4
# ...   ...    ...        ...            ...            ...               ...
# 1576   28   Male   Salaried        Married  Post Graduate                 2
# 1577   23   Male   Salaried         Single       Graduate                 2
# 1578   23   Male   Business        Married       Graduate                 4
# 1579   25   Male   Business        Married  Post Graduate                 3
# 1580   28   Male   Salaried        Married       Graduate                 4
#
# ...

# %%
df.describe()
# Out:
#                Age  No_of_Dependents        Salary  Partner_salary  \
# count  1581.000000       1581.000000   1581.000000     1581.000000
# mean     32.211259          2.457938  59732.447818    19720.430108
# std       9.125477          0.943483  14278.642665    19480.214404
# min      22.000000          0.000000  30000.000000        0.000000
# 25%      25.000000          2.000000  51000.000000        0.000000
# 50%      29.000000          2.000000  59000.000000    25000.000000
# 75%      38.000000          3.000000  71000.000000    38000.000000
# max      60.000000          4.000000  90000.000000    80000.000000
#
#         Total_salary         Price
# count    1581.000000   1581.000000
# mean    79452.877925  35597.722960
# std     24855.936043  13633.636545
# min     30000.000000  18000.000000
# 25%     61000.000000  25000.000000
# 50%     78000.000000  31000.000000
# 75%     96000.000000  47000.000000
# max    158000.000000  70000.000000

# %%
df.groupby('Gender').value_counts()
# Out:
# Gender  Age  Profession  Marital_status  Education      No_of_Dependents  Personal_loan  House_loan  Partner_working  Salary  Partner_salary  Total_salary  Price  Make
# Female  22   Salaried    Married         Graduate       3                 No             No          Yes              34000   28000           62000         31000  Hatchback    1
#                                          Post Graduate  2                 No             No          Yes              52000   30000           82000         23000  Hatchback    1
#                                                         4                 No             No          Yes              56000   32000           88000         28000  Hatchback    1
#         23   Salaried    Married         Post Graduate  2                 Yes            No          Yes              59000   32000           91000         27000  Hatchback    1
# ...

# %%
df.groupby(['Education','Gender'])['Price'].mean()
# Out:
# Education      Gender
# Graduate       Female    48920.289855
#                Male      31986.899563
# Post Graduate  Female    46827.225131
#                Male      32663.727960
# Name: Price, dtype: float64

# %%
df.groupby(['Personal_loan'])['Price'].mean()
# Out:
# Personal_loan
# No     36742.712294
# Yes    34457.070707
# Name: Price, dtype: float64
